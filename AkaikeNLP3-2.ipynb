# %% [markdown]
# **Problem Statement:**
#
# •	Objective 1: Get the most frequent entities from the tweets.
#
# •	Objective 2: Find out the sentiment/polarity of each author towards each of the entities.
#
# **Technology/Tools used:**
#
# •	Spacy for tokenization, stop words removal, named entity recognition.
#
# •	Scispacy (“en_ner_bc5cdr_md” module having labels “Entity” for named entity recognition. (medical or bi medical named entities)
#
# •	“en_core_sci_lg” module is used to cater to clinical dataset i.e; “tweets.json”
#
# •	Pandas for analyzing the dataset.
#
# •	Json to reads the dataset to Dataframe.
#
# •	Natural Language Processing library “SentimentIntensityAnalyzer”, Valence Aware Dictionary or Vader for sentiment Reasoning.
#
# **Approach followed:**
#
# Step 1:  Installed spacy.
#
# Step 2:  Imported and loaded scispacy and its biomedical module “en_ner_bc5cdr_md”.
#
# Step 3:  “Json” format read to Dataframe using orientation “index”
#
# Step 4:  Cleaned “tweet_text” column.
#
# •	No duplicates or missing values in the Dataframe.
#
# •	Removed punctuations, emoji s and digits,
#
# •	Removed hyper link and hashtags,
#
# •	Removed words less than 2 characters
#
# •	Changed to lower case,
#
# •	Removed extra trailing spaces,
#
# •	Created tokens,
#
# •	Removed stop words
#
# Step 5:  Extracted entity from “cleaned_tweet_text” column.
#
# Step 6:  Frequency of entities (solution to problem statement 1)
#
# Step 7:  Calculated polarity on each entity.
#
# Step 8:  Authors' sentiment analysis (solution to problem statement 2)
#
# **Approach to solve the problem :**
#
# •	Spacy module “en_core_web_sm” did not recognise context related entity, tried few clinical module but  “en_ner_bc5cdr_md” biomedical  module of scispacy solved this problem.
#
# **Conclusion:**
#
# •	Data Cleansing and Entities Extraction were a crucial parts of the solution. Removing unnecessary elements from “tweet_text” consumed most of the time.
#
# •	Entities Extraction is a key point in the solution. Finding the right entities defines extracting the right phrases from the tweets on which the core meaning of tweets relies on.
#
# •	Then, there comes extracting the sentiments of each entities from the tweets with the help of "NLTK package SentimentIntensityAnalyzer" .

# %% [markdown]
# # **Installing required Packages**

# %%
# !pip install spacy

#medical or bi medical named entities
# !pip install scispacy

#en_ner_bc5cdr_md - chemical disease relation (scispacy module)
#!pip install https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.5.1/en_ner_bc5cdr_md-0.5.1.tar.gz

#en_core_sci_lg
# !pip install https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.5.1/en_core_sci_lg-0.5.1.tar.gz

#en_ner_craft_md
#!pip install https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.5.1/en_ner_craft_md-0.5.1.tar.gz

#en_ner_jnlpba_md
#!pip install https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.5.1/en_ner_jnlpba_md-0.5.1.tar.gz

#en_ner_bionlp13cg_md
#!pip install https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.5.1/en_ner_bionlp13cg_md-0.5.1.tar.gz
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: spacy in /usr/local/lib/python3.8/dist-packages (3.4.4)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.8/dist-packages (from spacy) (1.10.4)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.8/dist-packages (from spacy) (2.0.8)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.8/dist-packages (from spacy) (0.10.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (4.64.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (21.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in /usr/local/lib/python3.8/dist-packages (from spacy) (3.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy) (3.0.8)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from spacy) (2.11.3)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (8.1.6)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (3.3.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (2.25.1)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.8/dist-packages (from spacy) (0.10.1)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.8/dist-packages (from spacy) (6.3.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (1.0.9)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from spacy) (57.4.0)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (0.7.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.8/dist-packages (from spacy) (2.4.5)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy) (2.0.7)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (1.0.4)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (1.21.6)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.0->spacy) (3.0.9)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.8/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy) (4.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (1.24.3)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.10)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy) (0.0.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.8/dist-packages (from typer<0.8.0,>=0.3.0->spacy) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from jinja2->spacy) (2.0.1)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: scispacy in /usr/local/lib/python3.8/dist-packages (0.5.1)
# Requirement already satisfied: pysbd in /usr/local/lib/python3.8/dist-packages (from scispacy) (0.3.4)
# Requirement already satisfied: spacy<3.5.0,>=3.4.0 in /usr/local/lib/python3.8/dist-packages (from scispacy) (3.4.4)
# Requirement already satisfied: nmslib>=1.7.3.6 in /usr/local/lib/python3.8/dist-packages (from scispacy) (2.1.1)
# Requirement already satisfied: conllu in /usr/local/lib/python3.8/dist-packages (from scispacy) (4.5.2)
# Requirement already satisfied: scikit-learn>=0.20.3 in /usr/local/lib/python3.8/dist-packages (from scispacy) (1.0.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.8/dist-packages (from scispacy) (1.2.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from scispacy) (1.21.6)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scispacy) (2.25.1)
# Requirement already satisfied: pybind11<2.6.2 in /usr/local/lib/python3.8/dist-packages (from nmslib>=1.7.3.6->scispacy) (2.6.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.8/dist-packages (from nmslib>=1.7.3.6->scispacy) (5.4.8)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.0.0->scispacy) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.0.0->scispacy) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.0.0->scispacy) (2022.12.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.0.0->scispacy) (2.10)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.20.3->scispacy) (1.7.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.20.3->scispacy) (3.1.0)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->scispacy) (0.7.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->scispacy) (21.3)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->scispacy) (1.0.9)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->scispacy) (1.10.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->scispacy) (6.3.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->scispacy) (0.10.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->scispacy) (2.4.5)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->scispacy) (8.1.6)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->scispacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->scispacy) (3.0.8)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->scispacy) (3.3.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->scispacy) (1.0.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->scispacy) (57.4.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->scispacy) (2.11.3)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->scispacy) (2.0.7)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->scispacy) (3.0.11)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->scispacy) (4.64.1)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->scispacy) (0.10.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.0->spacy<3.5.0,>=3.4.0->scispacy) (3.0.9)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.8/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.5.0,>=3.4.0->scispacy) (4.4.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->scispacy) (0.0.3)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->scispacy) (0.7.9)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.8/dist-packages (from typer<0.8.0,>=0.3.0->spacy<3.5.0,>=3.4.0->scispacy) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from jinja2->spacy<3.5.0,>=3.4.0->scispacy) (2.0.1)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.5.1/en_core_sci_lg-0.5.1.tar.gz
#   Using cached https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.5.1/en_core_sci_lg-0.5.1.tar.gz (532.3 MB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: spacy<3.5.0,>=3.4.1 in /usr/local/lib/python3.8/dist-packages (from en-core-sci-lg==0.5.1) (3.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.1->en-core-sci-lg==0.5.1) (21.3)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.1->en-core-sci-lg==0.5.1) (1.0.9)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.1->en-core-sci-lg==0.5.1) (1.21.6)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.1->en-core-sci-lg==0.5.1) (8.1.6)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.1->en-core-sci-lg==0.5.1) (1.0.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.1->en-core-sci-lg==0.5.1) (2.11.3)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.1->en-core-sci-lg==0.5.1) (3.0.8)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.1->en-core-sci-lg==0.5.1) (3.3.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.1->en-core-sci-lg==0.5.1) (1.10.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.1->en-core-sci-lg==0.5.1) (3.0.11)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.1->en-core-sci-lg==0.5.1) (0.10.1)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.1->en-core-sci-lg==0.5.1) (0.10.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.1->en-core-sci-lg==0.5.1) (2.0.8)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.1->en-core-sci-lg==0.5.1) (2.25.1)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.1->en-core-sci-lg==0.5.1) (0.7.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.1->en-core-sci-lg==0.5.1) (2.0.7)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.1->en-core-sci-lg==0.5.1) (4.64.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.1->en-core-sci-lg==0.5.1) (2.4.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.1->en-core-sci-lg==0.5.1) (57.4.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.1->en-core-sci-lg==0.5.1) (6.3.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.0->spacy<3.5.0,>=3.4.1->en-core-sci-lg==0.5.1) (3.0.9)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.8/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.5.0,>=3.4.1->en-core-sci-lg==0.5.1) (4.4.0)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.1->en-core-sci-lg==0.5.1) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.1->en-core-sci-lg==0.5.1) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.1->en-core-sci-lg==0.5.1) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.1->en-core-sci-lg==0.5.1) (1.24.3)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.1->en-core-sci-lg==0.5.1) (0.0.3)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.1->en-core-sci-lg==0.5.1) (0.7.9)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.8/dist-packages (from typer<0.8.0,>=0.3.0->spacy<3.5.0,>=3.4.1->en-core-sci-lg==0.5.1) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from jinja2->spacy<3.5.0,>=3.4.1->en-core-sci-lg==0.5.1) (2.0.1)

# %% [markdown]
# # **Importing required Library**

# %%
#Importing Pandas for data analysis and work with dataframe
import pandas as pd
#Importing numpy to working with arrays 
import numpy as np 
#Importing json to read the .json file
import json
#Importing re for regular expression operation
import re

#importing scipacy packages
import spacy
import scispacy
#import en_ner_bc5cdr_md
#import en_ner_craft_md
#import en_ner_bionlp13cg_md
#import en_ner_jnlpha_md
import en_core_sci_lg

#importing _________
#import en_core_web_sm

import nltk
nltk.download('averaged_perceptron_tagger')

import nltk
nltk.download('stopwords')
nltk.download('brown')
nltk.download('wordnet')
nltk.download('brown')
nltk.download('punkt')
# Out:
# /usr/local/lib/python3.8/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# # **Loading necessary Modules**

# %%
#loading modules
#ner_bc = en_ner_bc5cdr_md.load()
#ner_cr = en_ner_craft_md.load()
#ner_bi = en_ner_bionlp13cg_md.load()
#ner_jn = en_ner_jnlpha_md.load()
#ner_web = en_core_web_sm.load()
ner_sci = en_core_sci_lg.load()

# %% [markdown]
# # **Reading the .json file to dataframe**

# %%
df = pd.read_json('/content/tweets.json',orient ='index')
df = df.reset_index(drop = False)
df
# Out:
#                               index        tweet_author  \
# 0     2013-07-18 09:39:46.071961602  Hematopoiesis News
# 1     2013-07-17 03:40:32.173842437    Michael Wang, MD
# 2     2013-07-15 15:41:16.553048065         1stOncology
# 3     2013-07-12 19:19:42.367813635           Toby Eyre
# 4     2013-07-04 12:40:34.334232586        Lymphoma Hub
# ...                             ...                 ...
# 43342 1987-06-19 12:17:53.643945985  Joy is a Lifestyle
# 43343 1987-06-19 12:06:26.675290112       𝓒𝓻𝓲𝔃𝔃𝔂 𝓟𝓮𝓻𝓻𝔂🌹
# 43344 1987-06-17 23:05:41.186953217               IQWiG
# 43345 1987-06-17 15:18:00.525635584           Medibooks
# 43346 1987-06-13 10:44:06.537678849           Medibooks
#
#                                               tweet_text
# 0      ⚕️ Scientists conducted a Phase II study of ac...
# 1      This phase 2 Acalabrutinib-Venetoclax (AV) tri...
# 2      #NICE backs #AstraZenecas #Calquence for #CLL ...
# 3      #acalabrutinib is a valuable option in pts int...
# 4      NICE has recommended the use of acalabrutinib ...
# ...                                                  ...
# 43342  Hanging out with Friends! :) #FF #CLL #Happine...
# 43343  Hanging out with Friends! :) #FF #CLL #Happine...
# 43344  Zusatznutzen von #Idelalisib ist weder für #CL...
# 43345  #Hematología PTK2 EXPRESSION AND IMMUNOCHEMOTH...
# 43346  #Hematología MUTATIONS IN TLR/MYD88 PATHWAY ID...
#
# [43347 rows x 3 columns]

# %% [markdown]
# # **Data Preprocessing (Cleaning the data)**

# %%
#checking missing values
df.isnull().sum()
# Out:
# index           0
# tweet_author    0
# tweet_text      0
# dtype: int64

# %%
#checking for duplicates
df.duplicated().sum()
# Out:
# 0

# %%
#removing hashtags (word starting with #)
df['tweet_text'] = df['tweet_text'].replace(r'#[\w]*', '', regex=True)
df["tweet_text"][0]
# Out:
# '⚕️ Scientists conducted a Phase II study of acalabrutinib in patients with relapsed/refractory  who were ibrutinib-intolerant, and found an overall response rate of 73%. \nhttps://t.co/eJ6m4QpC5P https://t.co/kuZz6ZO47r'

# %%
#removing https links
df['tweet_text'] = df['tweet_text'].replace(r'http\S+', '', regex=True).replace(r'www\S+', '', regex=True)
df["tweet_text"][0]
# Out:
# '⚕️ Scientists conducted a Phase II study of acalabrutinib in patients with relapsed/refractory  who were ibrutinib-intolerant, and found an overall response rate of 73%. \n '

# %%
# Replacing punctuations with space
df['tweet_text'] = df['tweet_text'].str.replace("[^a-zA-Z]", " ",regex = True)
df["tweet_text"][0]
# Out:
# '   Scientists conducted a Phase II study of acalabrutinib in patients with relapsed refractory  who were ibrutinib intolerant  and found an overall response rate of        '

# %%
# make entire text lowercase
df['tweet_text'] = [row.lower() for row in df['tweet_text']]
df["tweet_text"][0]
# Out:
# '   scientists conducted a phase ii study of acalabrutinib in patients with relapsed refractory  who were ibrutinib intolerant  and found an overall response rate of        '

# %%
# #remove words with len < 3
df['tweet_text'] = df['tweet_text'].apply(lambda x: ' '.join([w for w in x.split() if len(w)>3]))
df["tweet_text"][0]
# Out:
# 'scientists conducted phase study acalabrutinib patients with relapsed refractory were ibrutinib intolerant found overall response rate'

# %%
#tokenization
#df["cleaned_tweet_text"] = df["tweet_text"].apply(lambda x: [t.text for t in ner_bc.tokenizer(x)])
#df
#df["cleaned_tweet_text"] = df["tweet_text"].apply(lambda x: ner_bc.tokenizer(x))
#df
df["cleaned_tweet_text"] = df["tweet_text"].apply(lambda x: ner_sci.tokenizer(x))
df
# Out:
#                               index        tweet_author  \
# 0     2013-07-18 09:39:46.071961602  Hematopoiesis News
# 1     2013-07-17 03:40:32.173842437    Michael Wang, MD
# 2     2013-07-15 15:41:16.553048065         1stOncology
# 3     2013-07-12 19:19:42.367813635           Toby Eyre
# 4     2013-07-04 12:40:34.334232586        Lymphoma Hub
# ...                             ...                 ...
# 43342 1987-06-19 12:17:53.643945985  Joy is a Lifestyle
# 43343 1987-06-19 12:06:26.675290112       𝓒𝓻𝓲𝔃𝔃𝔂 𝓟𝓮𝓻𝓻𝔂🌹
# 43344 1987-06-17 23:05:41.186953217               IQWiG
# 43345 1987-06-17 15:18:00.525635584           Medibooks
# 43346 1987-06-13 10:44:06.537678849           Medibooks
#
#                                               tweet_text  \
# 0      scientists conducted phase study acalabrutinib...
# 1      this phase acalabrutinib venetoclax trial that...
# 2                                                  backs
# 3      valuable option intolerant further valuable da...
# 4      nice recommended acalabrutinib patients with t...
# ...                                                  ...
# 43342                               hanging with friends
# 43343                               hanging with friends
# 43344  zusatznutzen weder noch refrakt follikul lymph...
# 43345  expression immunochemotherapy outcome chronic ...
# 43346  mutations pathway identify subset young chroni...
#
#                                       cleaned_tweet_text
# 0      (scientists, conducted, phase, study, acalabru...
# 1      (this, phase, acalabrutinib, venetoclax, trial...
# 2                                                (backs)
# 3      (valuable, option, intolerant, further, valuab...
# 4      (nice, recommended, acalabrutinib, patients, w...
# ...                                                  ...
# 43342                           (hanging, with, friends)
# 43343                           (hanging, with, friends)
# 43344  (zusatznutzen, weder, noch, refrakt, follikul,...
# 43345  (expression, immunochemotherapy, outcome, chro...
# 43346  (mutations, pathway, identify, subset, young, ...
#
# [43347 rows x 4 columns]

# %%
#stopwords removal
#df["cleaned_tweet_text"] = df["cleaned_tweet_text"].apply(lambda x: [token.text for token in ner_bc(x) if not token.is_stop])
#df
df["cleaned_tweet_text"] = df["cleaned_tweet_text"].apply(lambda x: [token.text for token in ner_sci(x) if not token.is_stop])
df
# Out:
#                               index        tweet_author  \
# 0     2013-07-18 09:39:46.071961602  Hematopoiesis News
# 1     2013-07-17 03:40:32.173842437    Michael Wang, MD
# 2     2013-07-15 15:41:16.553048065         1stOncology
# 3     2013-07-12 19:19:42.367813635           Toby Eyre
# 4     2013-07-04 12:40:34.334232586        Lymphoma Hub
# ...                             ...                 ...
# 43342 1987-06-19 12:17:53.643945985  Joy is a Lifestyle
# 43343 1987-06-19 12:06:26.675290112       𝓒𝓻𝓲𝔃𝔃𝔂 𝓟𝓮𝓻𝓻𝔂🌹
# 43344 1987-06-17 23:05:41.186953217               IQWiG
# 43345 1987-06-17 15:18:00.525635584           Medibooks
# 43346 1987-06-13 10:44:06.537678849           Medibooks
#
#                                               tweet_text  \
# 0      scientists conducted phase study acalabrutinib...
# 1      this phase acalabrutinib venetoclax trial that...
# 2                                                  backs
# 3      valuable option intolerant further valuable da...
# 4      nice recommended acalabrutinib patients with t...
# ...                                                  ...
# 43342                               hanging with friends
# 43343                               hanging with friends
# 43344  zusatznutzen weder noch refrakt follikul lymph...
# 43345  expression immunochemotherapy outcome chronic ...
# 43346  mutations pathway identify subset young chroni...
#
#                                       cleaned_tweet_text
# 0      [scientists, conducted, phase, study, acalabru...
# 1      [phase, acalabrutinib, venetoclax, trial, recr...
# 2                                                [backs]
# 3      [valuable, option, intolerant, valuable, data,...
# 4      [nice, recommended, acalabrutinib, patients, t...
# ...                                                  ...
# 43342                                 [hanging, friends]
# 43343                                 [hanging, friends]
# 43344  [zusatznutzen, weder, noch, refrakt, follikul,...
# 43345  [expression, immunochemotherapy, outcome, chro...
# 43346  [mutations, pathway, identify, subset, young, ...
#
# [43347 rows x 4 columns]

# %%
df["cleaned_tweet_text"] = df["cleaned_tweet_text"].astype(str)

# %%
df["cleaned_tweet_text"][0]

# %%
df['cleaned_tweet_text'] = df['cleaned_tweet_text'].str.replace("[^a-zA-Z]", " ",regex = True)
df["cleaned_tweet_text"][0]
# Out:
# '  scientists    conducted    phase    study    acalabrutinib    patients    relapsed    refractory    ibrutinib    intolerant    found    overall    response    rate  '

# %% [markdown]
# # ***SciSpacy Named Entity Recognition(NER)***

# %% [markdown]
# ***Application on DataFrame***

# %%
print(list(ner_sci.component_names))
# Out:
# ['tok2vec', 'tagger', 'attribute_ruler', 'lemmatizer', 'parser', 'ner']

# %%
print(list(ner_sci.get_pipe("ner").labels))
# Out:
# ['ENTITY']

# %%
def add_bc(abstractList, doiList):
    i = 0
    table= {"Author":[], "Entity":[], "Class":[]}
    for doc in ner_sci.pipe(abstractList):
        doi = doiList[i]
        for x in doc.ents:
          table["Author"].append(doi)
          table["Entity"].append(x.text)
          table["Class"].append(x.label_)
        i +=1
    return table

# %%
#meta_df = pd.read_csv("/content/sample.csv")

#Sort out blank abstracts
#df = meta_df.dropna(subset=['abstract'])

#Create lists
doiList = df['tweet_author'].tolist()
abstractList = df['cleaned_tweet_text'].tolist()

#Add all entity value pairs to table (run one at a time, each ones takes ~20 min)
table = add_bc(abstractList, doiList)

# table = add_bc(abstractList, doiList)

# table = add_bi(abstractList, doiList)

# table = add_jn(abstractList, doiList)

#Turn table into an exportable CSV file (returns normalized file of entity/value pairs)
ner_df = pd.DataFrame(table)
#trans_df.to_csv ("Entity_pairings.csv", index=False)

# %%
#trans_df = pd.DataFrame(table)
ner_df[:30]
#trans_df.to_csv("Entity.csv",index = False)
# Out:
#                             Author         Entity   Class
# 0               Hematopoiesis News     scientists  ENTITY
# 1               Hematopoiesis News  acalabrutinib  ENTITY
# 2               Hematopoiesis News       patients  ENTITY
# 3               Hematopoiesis News       relapsed  ENTITY
# 4               Hematopoiesis News      ibrutinib  ENTITY
# 5               Hematopoiesis News     intolerant  ENTITY
# 6               Hematopoiesis News       response  ENTITY
# 7               Hematopoiesis News           rate  ENTITY
# 8                 Michael Wang, MD  acalabrutinib  ENTITY
# 9                 Michael Wang, MD     venetoclax  ENTITY
# 10                Michael Wang, MD          trial  ENTITY
# 11                Michael Wang, MD  acalabrutinib  ENTITY
# 12                Michael Wang, MD       patients  ENTITY
# 13                Michael Wang, MD       relapsed  ENTITY
# 14                Michael Wang, MD     respondent  ENTITY
# 15                       Toby Eyre     intolerant  ENTITY
# 16                       Toby Eyre           data  ENTITY
# 17                       Toby Eyre          early  ENTITY
# 18                    Lymphoma Hub    recommended  ENTITY
# 19                    Lymphoma Hub  acalabrutinib  ENTITY
# 20                    Lymphoma Hub       patients  ENTITY
# 21                    Lymphoma Hub      treatment  ENTITY
# 22                    David Ledger      calquence  ENTITY
# 23            N Wales Cancer Forum      decisions  ENTITY
# 24  European Pharmaceutical Review      calquence  ENTITY
# 25  European Pharmaceutical Review  acalabrutinib  ENTITY
# 26  European Pharmaceutical Review   chemotherapy  ENTITY
# 27  European Pharmaceutical Review    monotherapy  ENTITY
# 28  European Pharmaceutical Review       patients  ENTITY
# 29  European Pharmaceutical Review        chronic  ENTITY

# %%
ner_df.duplicated().value_counts()
# Out:
# False    58701
# True     52478
# dtype: int64

# %%
ner_df.drop_duplicates(inplace = True)
ner_df
# Out:
#                     Author              Entity   Class
# 0       Hematopoiesis News          scientists  ENTITY
# 1       Hematopoiesis News       acalabrutinib  ENTITY
# 2       Hematopoiesis News            patients  ENTITY
# 3       Hematopoiesis News            relapsed  ENTITY
# 4       Hematopoiesis News           ibrutinib  ENTITY
# ...                    ...                 ...     ...
# 111170          Micheál 🇮🇪            lifetime  ENTITY
# 111172       𝓒𝓻𝓲𝔃𝔃𝔂 𝓟𝓮𝓻𝓻𝔂🌹             friends  ENTITY
# 111174           Medibooks  immunochemotherapy  ENTITY
# 111175           Medibooks             outcome  ENTITY
# 111176           Medibooks              subset  ENTITY
#
# [58701 rows x 3 columns]

# %%
ner_df[ner_df["Entity"] == "na"]
  
#ner_df_cleaned = ner_df[ner_df['Entity'] != "na"][["Author","Entity","Class"]]
#ner_df_cleaned
ner_df_cleaned = ner_df

# %%
freq = pd.DataFrame(ner_df_cleaned['Entity'].value_counts()).reset_index().rename(columns = {"index":"Entity","Entity":"Frequency"})
freq[:20]
freq.to_csv("objective1.csv", encoding='utf-8',index = False)

# %%
df5 = pd.read_csv("/content/objective1.csv")
df5
# Out:
#              Entity  Frequency
# 0          patients       2146
# 1           chronic       1628
# 2     acalabrutinib       1444
# 3         calquence       1349
# 4         treatment       1291
# ...             ...        ...
# 7233     astronauts          1
# 7234           sigo          1
# 7235         presby          1
# 7236      snapshots          1
# 7237         subset          1
#
# [7238 rows x 2 columns]

# %% [markdown]
# # ***Part II - Sentimental analysis/Polarity***

# %%
polarity_df = ner_df_cleaned.copy()
polarity_df
# Out:
#                     Author              Entity   Class
# 0       Hematopoiesis News          scientists  ENTITY
# 1       Hematopoiesis News       acalabrutinib  ENTITY
# 2       Hematopoiesis News            patients  ENTITY
# 3       Hematopoiesis News            relapsed  ENTITY
# 4       Hematopoiesis News           ibrutinib  ENTITY
# ...                    ...                 ...     ...
# 111170          Micheál 🇮🇪            lifetime  ENTITY
# 111172       𝓒𝓻𝓲𝔃𝔃𝔂 𝓟𝓮𝓻𝓻𝔂🌹             friends  ENTITY
# 111174           Medibooks  immunochemotherapy  ENTITY
# 111175           Medibooks             outcome  ENTITY
# 111176           Medibooks              subset  ENTITY
#
# [58701 rows x 3 columns]

# %%
#polarity = en_ner_bc5cdr_md.load()
#polarity = en_core_web_sm.load()
polarity = en_core_sci_lg.load()

# %%
# !pip install vaderSentiment
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: vaderSentiment in /usr/local/lib/python3.8/dist-packages (3.3.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from vaderSentiment) (2.25.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->vaderSentiment) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->vaderSentiment) (1.24.3)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->vaderSentiment) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->vaderSentiment) (2022.12.7)

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from nltk.sentiment.util import *

#Sentiment Analysis
SIA = SentimentIntensityAnalyzer()

polarity_df["Entity"]= polarity_df["Entity"].astype(str)
# Applying Model, Variable Creation
polarity_df['Polarity Score'] = polarity_df["Entity"].apply(lambda x:SIA.polarity_scores(x)['compound'])
polarity_df['Neutral Score'] = polarity_df["Entity"].apply(lambda x:SIA.polarity_scores(x)['neu'])
polarity_df['Negative Score'] = polarity_df["Entity"].apply(lambda x:SIA.polarity_scores(x)['neg'])
polarity_df['Positive Score'] = polarity_df["Entity"].apply(lambda x:SIA.polarity_scores(x)['pos'])


# Converting 0 to 1 Decimal Score to a Categorical Variable
polarity_df['overall polarity']=''
polarity_df.loc[polarity_df['Polarity Score'] > 0,'overall polarity']='Positive'
#polarity_df.loc[polarity_df['Polarity Score'] == 0,'overall polarity']='Neutral'
polarity_df.loc[polarity_df['Polarity Score'] <= 0,'overall polarity']='Negative'
polarity_df[:30]
# Out:
#                             Author         Entity   Class  Polarity Score  \
# 0               Hematopoiesis News     scientists  ENTITY          0.0000
# 1               Hematopoiesis News  acalabrutinib  ENTITY          0.0000
# 2               Hematopoiesis News       patients  ENTITY          0.0000
# 3               Hematopoiesis News       relapsed  ENTITY          0.0000
# 4               Hematopoiesis News      ibrutinib  ENTITY          0.0000
# 5               Hematopoiesis News     intolerant  ENTITY          0.0000
# 6               Hematopoiesis News       response  ENTITY          0.0000
# 7               Hematopoiesis News           rate  ENTITY          0.0000
# 8                 Michael Wang, MD  acalabrutinib  ENTITY          0.0000
# 9                 Michael Wang, MD     venetoclax  ENTITY          0.0000
# 10                Michael Wang, MD          trial  ENTITY          0.0000
# 12                Michael Wang, MD       patients  ENTITY          0.0000
# 13                Michael Wang, MD       relapsed  ENTITY          0.0000
# 14                Michael Wang, MD     respondent  ENTITY          0.0000
# 15                       Toby Eyre     intolerant  ENTITY          0.0000
# 16                       Toby Eyre           data  ENTITY          0.0000
# 17                       Toby Eyre          early  ENTITY          0.0000
# 18                    Lymphoma Hub    recommended  ENTITY          0.2023
# 19                    Lymphoma Hub  acalabrutinib  ENTITY          0.0000
# 20                    Lymphoma Hub       patients  ENTITY          0.0000
# 21                    Lymphoma Hub      treatment  ENTITY          0.0000
# 22                    David Ledger      calquence  ENTITY          0.0000
# 23            N Wales Cancer Forum      decisions  ENTITY          0.0000
# 24  European Pharmaceutical Review      calquence  ENTITY          0.0000
# 25  European Pharmaceutical Review  acalabrutinib  ENTITY          0.0000
# 26  European Pharmaceutical Review   chemotherapy  ENTITY          0.0000
# 27  European Pharmaceutical Review    monotherapy  ENTITY          0.0000
# 28  European Pharmaceutical Review       patients  ENTITY          0.0000
# 29  European Pharmaceutical Review        chronic  ENTITY          0.0000
# 30                  Graham Collins     responding  ENTITY          0.0000
#
#     Neutral Score  Negative Score  Positive Score overall polarity
# 0             1.0             0.0             0.0         Negative
# 1             1.0             0.0             0.0         Negative
# 2             1.0             0.0             0.0         Negative
# 3             1.0             0.0             0.0         Negative
# 4             1.0             0.0             0.0         Negative
# 5             1.0             0.0             0.0         Negative
# 6             1.0             0.0             0.0         Negative
# 7             1.0             0.0             0.0         Negative
# 8             1.0             0.0             0.0         Negative
# 9             1.0             0.0             0.0         Negative
# 10            1.0             0.0             0.0         Negative
# 12            1.0             0.0             0.0         Negative
# 13            1.0             0.0             0.0         Negative
# 14            1.0             0.0             0.0         Negative
# 15            1.0             0.0             0.0         Negative
# 16            1.0             0.0             0.0         Negative
# 17            1.0             0.0             0.0         Negative
# 18            0.0             0.0             1.0         Positive
# 19            1.0             0.0             0.0         Negative
# 20            1.0             0.0             0.0         Negative
# 21            1.0             0.0             0.0         Negative
# 22            1.0             0.0             0.0         Negative
# 23            1.0             0.0             0.0         Negative
# 24            1.0             0.0             0.0         Negative
# 25            1.0             0.0             0.0         Negative
# 26            1.0             0.0             0.0         Negative
# 27            1.0             0.0             0.0         Negative
# 28            1.0             0.0             0.0         Negative
# 29            1.0             0.0             0.0         Negative
# 30            1.0             0.0             0.0         Negative

# %%
polarity_df["overall polarity"].value_counts()
# Out:
# Negative    54689
# Positive     4012
# Name: overall polarity, dtype: int64

# %%
polarity_df.columns
# Out:
# Index(['Author', 'Entity', 'Class', 'Polarity Score', 'Neutral Score',
#        'Negative Score', 'Positive Score', 'overall polarity'],
#       dtype='object')

# %%
del polarity_df["Polarity Score"]
#,"Neutral Score","Negative Score","Positive Score","Class"])

# %%
del polarity_df["Neutral Score"]

# %%
del polarity_df["Negative Score"]

# %%
del polarity_df["Positive Score"]

# %%
del polarity_df["Class"]

# %%
polarity_df
# Out:
#                     Author              Entity overall polarity
# 0       Hematopoiesis News          scientists         Negative
# 1       Hematopoiesis News       acalabrutinib         Negative
# 2       Hematopoiesis News            patients         Negative
# 3       Hematopoiesis News            relapsed         Negative
# 4       Hematopoiesis News           ibrutinib         Negative
# ...                    ...                 ...              ...
# 111170          Micheál 🇮🇪            lifetime         Negative
# 111172       𝓒𝓻𝓲𝔃𝔃𝔂 𝓟𝓮𝓻𝓻𝔂🌹             friends         Positive
# 111174           Medibooks  immunochemotherapy         Negative
# 111175           Medibooks             outcome         Negative
# 111176           Medibooks              subset         Negative
#
# [58701 rows x 3 columns]

# %%
polarity_df.to_csv("objective2.csv", encoding='utf-8',index = False)
